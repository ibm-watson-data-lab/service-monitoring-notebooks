# %%
# see https://pypi.python.org/pypi/redis/
# !pip install redis

# %% [markdown]
# #### TODO: Configure the following variables
# Specify your Redis URL

# %%
# @hidden_cell
# redis://admin:**password**@**host**:**port**
uri = None

# %%
import redis
r = redis.StrictRedis.from_url(uri)

# %%
# CONFIG GET databases
r.config_get('databases')

# %%
r.info('keyspace')

# %% [markdown]
# #### TODO: Replace the following variables
# Specify an existing hash

# %%
# https://redis.io/commands/hgetall
myhash = None
r.hgetall(myhash)
